# %%
# from src.utils import model_selection, create_plots
from src.utils import create_plots, model_comparasion
# Replace model_selection with model_selection_parallel 
from src.load_results import model_selection_parallel as model_selection

# %%
Vanilla_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"vanilla/Bios_gender",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= ("0","1","2","3","4"),
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    n_jobs=5,
    index_column_names = ["lr"],
    save_path = "results/Bios_gender_Vanilla_df.pkl"
    )
# Out:
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:   11.2s remaining:   16.9s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:   12.2s finished

# %%
Adv_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"hypertune4/Bios_gender",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= "Adv",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    save_path = "results/Bios_gender_Adv_df.pkl"
    )
# Out:
# [Parallel(n_jobs=20)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  32 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=20)]: Done 122 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=20)]: Done 205 out of 205 | elapsed:  2.2min finished

# %%
create_plots(input_df = Adv_df)
# Out:
#             index epoch      dev_fairness           dev_performance            \
#                    mean  var         mean       var            mean       var
# 20  (1.0, 1, 0.0)   8.4  6.3     0.909428  0.000069        0.814308  0.000002
#
#      dev_DTO           test_fairness           test_performance            \
#         mean       var          mean       var             mean       var
# 20  0.003043  0.000002      0.907356  0.000059         0.816637  0.000005
#
#     test_DTO           final_DTO log_lambda
#         mean       var
# 20  0.007369  0.000018  0.009591        0.0

# %%
DAdv_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"hypertune5/Bios_gender",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= "R_DAdv",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    save_path = "results/Bios_gender_DAdv_df.pkl"
    )
# Out:
# [Parallel(n_jobs=20)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  32 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=20)]: Done 122 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=20)]: Done 248 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=20)]: Done 410 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=20)]: Done 608 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=20)]: Done 842 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=20)]: Done 1025 out of 1025 | elapsed: 10.4min finished

# %%
create_plots(input_df = DAdv_df)
# Out:
#               index epoch      dev_fairness           dev_performance  \
#                      mean  var         mean       var            mean
# 103  (1.0, 3, 10.0)   7.2  6.7     0.909024  0.000014        0.814253
#
#                 dev_DTO           test_fairness           test_performance  \
#           var      mean       var          mean       var             mean
# 103  0.000003  0.004457  0.000009      0.910691  0.000046         0.817499
#
#                test_DTO           final_DTO log_lambda
#           var      mean       var
# 103  0.000002  0.005951  0.000008  0.009903        0.0

# %%
GAdv_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"hypertune4/Bios_gender",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= "GAdv",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    save_path = "results/Bios_gender_GAdv_df.pkl"
    )
# Out:
# [Parallel(n_jobs=20)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  32 tasks      | elapsed:   23.1s
# [Parallel(n_jobs=20)]: Done 122 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=20)]: Done 205 out of 205 | elapsed:  2.2min finished

# %%
create_plots(
    input_df = GAdv_df
    )
# Out:
#                            index epoch       dev_fairness            \
#                                   mean   var         mean       var
# 25  (3.1622776601683795, 1, 0.0)   8.2  40.7     0.900109  0.000021
#
#    dev_performance             dev_DTO           test_fairness            \
#               mean       var      mean       var          mean       var
# 25        0.811473  0.000009  0.006891  0.000004      0.896772  0.000045
#
#    test_performance            test_DTO           final_DTO log_lambda
#                mean       var      mean       var
# 25          0.81435  0.000007  0.007782  0.000027   0.01728        0.5

# %%
BTGAdv_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"hypertune4/Bios_gender",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= "BTGAdv",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    save_path = "results/Bios_gender_BTGAdv_df.pkl"
    )
# Out:
# [Parallel(n_jobs=20)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  32 tasks      | elapsed:   23.3s
# [Parallel(n_jobs=20)]: Done 122 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=20)]: Done 205 out of 205 | elapsed:  2.2min finished

# %%
create_plots(
    input_df = BTGAdv_df, 
    )
# Out:
#                           index epoch      dev_fairness            \
#                                  mean  var         mean       var
# 29  (7.943282347242821, 1, 0.0)   6.6  6.8     0.896856  0.000061
#
#    dev_performance             dev_DTO           test_fairness            \
#               mean       var      mean       var          mean       var
# 29        0.812053  0.000007  0.009905  0.000068      0.892797  0.000016
#
#    test_performance            test_DTO           final_DTO log_lambda
#                mean       var      mean       var
# 29         0.815086  0.000004  0.011832  0.000095  0.090269        0.9

# %%
GDAdv_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"hypertune5/Bios_gender",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= "GDAdv",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    save_path = "results/Bios_gender_GDAdv_df.pkl"
    )
# Out:
# [Parallel(n_jobs=20)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  32 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=20)]: Done 122 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=20)]: Done 248 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=20)]: Done 410 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=20)]: Done 608 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=20)]: Done 777 out of 777 | elapsed:  8.0min finished

# %%
create_plots(
    input_df = GDAdv_df, 
    )
# Out:
#                 index epoch       dev_fairness           dev_performance  \
#                        mean   var         mean       var            mean
# 116  (10.0, 3, 100.0)  13.2  38.7     0.912063  0.000037        0.809207
#
#                 dev_DTO           test_fairness           test_performance  \
#           var      mean       var          mean       var             mean
# 116  0.000015  0.009172  0.000015      0.902542  0.000076         0.812294
#
#                test_DTO           final_DTO log_lambda
#           var      mean       var
# 116  0.000019  0.012397  0.000022  0.020846        1.0

# %%
BTGDAdv_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"hypertune4/Bios_gender",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= "DAdv",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    save_path = "results/Bios_gender_BTGDAdv_df.pkl",
    )
# Out:
# [Parallel(n_jobs=20)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  32 tasks      | elapsed:   22.8s
# [Parallel(n_jobs=20)]: Done 122 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=20)]: Done 248 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=20)]: Done 410 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=20)]: Done 608 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=20)]: Done 842 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=20)]: Done 1025 out of 1025 | elapsed: 10.5min finished

# %%
create_plots(
    input_df = BTGDAdv_df, 
    )
# Out:
#                             index epoch       dev_fairness            \
#                                    mean   var         mean       var
# 166  (19.952623149688808, 3, 0.1)   6.0  13.5     0.905404  0.000146
#
#     dev_performance             dev_DTO           test_fairness            \
#                mean       var      mean       var          mean       var
# 166        0.804384  0.000016  0.020812  0.000105      0.899018  0.000073
#
#     test_performance            test_DTO           final_DTO log_lambda
#                 mean       var      mean       var
# 166         0.807934  0.000016  0.030827  0.000306  0.096518        1.3

# %%
FairBatch_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"FairBatch/Bios_gender",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= "FairBatch",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    index_column_names = ['DyBTObj', 'DyBTalpha', 'DyBTinit'],
    save_path = "results/Bios_gender_FairBatch_df.pkl"
    )
# Out:
# [Parallel(n_jobs=20)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  32 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=20)]: Done 122 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=20)]: Done 205 out of 205 | elapsed:  1.9min finished

# %%
BTFairBatch_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"FairBatch/Bios_gender",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= "BTInitFairBatch",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    index_column_names = ['DyBTObj', 'DyBTalpha', 'DyBTinit'],
    save_path = "results/Bios_gender_BTFairBatch_df.pkl"
    )
# Out:
# [Parallel(n_jobs=20)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  32 tasks      | elapsed:   21.5s
# [Parallel(n_jobs=20)]: Done 122 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=20)]: Done 205 out of 205 | elapsed:  1.9min finished

# %%
INLP_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"INLP/Bios_gender",
    checkpoint_dir= "models",
    checkpoint_name= "INLP",
    model_id= "INLP_True",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    index_column_names = ['INLP_by_class', 'INLP_discriminator_reweighting', 'INLP_min_acc'],
    save_path = "results/Bios_gender_INLP_df.pkl",
    return_all=True
    )
# Out:
# 100%|██████████| 1/1 [00:02<00:00,  2.88s/it]

# %%
OldFairBatch_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"Original_FairBatch/Bios_gender",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= "Original_FairBatch",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    index_column_names = ['DyBTObj', 'DyBTalpha', 'DyBTinit'],
    save_path = "results/Bios_gender_OldFairBatch_df.pkl",
    n_jobs=0
    )
# Out:
# 100%|██████████| 105/105 [15:21<00:00,  8.78s/it]

# %%
BTEO_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"GatedBT/Bios_gender",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= ("GatedBTEO_Resampling_EO_False"),
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    n_jobs=10,
    index_column_names = ["BT", "BTObj", "gated"],
    save_path = "results/Bios_gender_BTEO_df.pkl"
    )
# Out:
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of   5 | elapsed:   10.0s remaining:   15.0s
# [Parallel(n_jobs=10)]: Done   5 out of   5 | elapsed:   11.7s finished

# %%
BTEO_df
# Out:
#                         epoch  dev_fairness  dev_performance   dev_DTO  \
# BT         BTObj gated
# Resampling EO    False     19      0.898234         0.841127  0.014461
#                  False      5      0.918655         0.834707  0.007192
#                  False      7      0.897336         0.834437  0.003229
#                  False     17      0.893883         0.839336  0.000000
#                  False     15      0.900715         0.836532  0.003582
#
#                         test_fairness  test_performance  test_DTO  \
# BT         BTObj gated
# Resampling EO    False       0.902465          0.840406  0.011912
#                  False       0.894908          0.834970  0.029892
#                  False       0.917067          0.836349  0.005036
#                  False       0.900181          0.840109  0.015695
#                  False       0.912228          0.839798  0.001640
#
#                                                                   opt_dir
# BT         BTObj gated
# Resampling EO    False  G:\Experimental_results\GatedBT\Bios_gender\Ga...
#                  False  G:\Experimental_results\GatedBT\Bios_gender\Ga...
#                  False  G:\Experimental_results\GatedBT\Bios_gender\Ga...
#                  False  G:\Experimental_results\GatedBT\Bios_gender\Ga...
#                  False  G:\Experimental_results\GatedBT\Bios_gender\Ga...

# %%
GatedBTEO_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"GatedBT/Bios_gender",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= "GatedBTEO_Resampling_EO_True",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    n_jobs=10,
    index_column_names = ["BT", "BTObj", "gated"],
    save_path = "results/Bios_gender_GatedBTEO_df.pkl"
    )
# Out:
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of   5 | elapsed:    8.6s remaining:   13.0s
# [Parallel(n_jobs=10)]: Done   5 out of   5 | elapsed:    9.4s finished

# %%
GatedBTEO_df
# Out:
#                         epoch  dev_fairness  dev_performance   dev_DTO  \
# BT         BTObj gated
# Resampling EO    True       4      0.890926         0.835451  0.002151
#                  True      14      0.899877         0.831295  0.003967
#                  True      14      0.890932         0.831599  0.004848
#                  True       4      0.899366         0.837512  0.003807
#                  True       5      0.891376         0.832207  0.004549
#
#                         test_fairness  test_performance  test_DTO  \
# BT         BTObj gated
# Resampling EO    True        0.896224          0.837363  0.011555
#                  True        0.901644          0.834794  0.003165
#                  True        0.918031          0.834780  0.005414
#                  True        0.907875          0.840244  0.018409
#                  True        0.896433          0.836227  0.003690
#
#                                                                   opt_dir
# BT         BTObj gated
# Resampling EO    True   G:\Experimental_results\GatedBT\Bios_gender\Ga...
#                  True   G:\Experimental_results\GatedBT\Bios_gender\Ga...
#                  True   G:\Experimental_results\GatedBT\Bios_gender\Ga...
#                  True   G:\Experimental_results\GatedBT\Bios_gender\Ga...
#                  True   G:\Experimental_results\GatedBT\Bios_gender\Ga...

# %%
_results_dict = {
    "Adv": Adv_df,
    "GAdv": GAdv_df,
    "DAdv": DAdv_df,
    "GDAdv": GDAdv_df,
    "BTGAdv": BTGAdv_df,
    "BTGDAdv": BTGDAdv_df,
    # "FairBatch": FairBatch_df,
    # "BTFairBatch": BTFairBatch_df,
    "INLP": INLP_df,
    "FairBatch":OldFairBatch_df,
}

_final_df = model_comparasion(
    results_dict = _results_dict,
    pareto_selection="test",
    )

# %%
_final_df = model_comparasion(
    results_dict = _results_dict,
    pareto_selection="dev",
    )

# %%
import pandas as pd
merged_GDAdv = pd.concat([GDAdv_df, BTGDAdv_df])
merged_GAdv = pd.concat([GAdv_df, BTGAdv_df])

# %%
_results_dict = {
    "Adv": Adv_df,
    "GAdv": merged_GAdv,
    "DAdv": DAdv_df,
    "GDAdv": merged_GDAdv,
    "FairBatch": OldFairBatch_df,
    # "BTFairBatch": BTFairBatch_df,
}

_final_df = model_comparasion(
    results_dict = _results_dict,
    pareto_selection="test",
    )

# %%
_results_dict = {
    "FairBatch": FairBatch_df,
    "BTFairBatch": BTFairBatch_df,
    "OldFairBatch":OldFairBatch_df,
}

_final_df = model_comparasion(
    results_dict = _results_dict,
    pareto_selection="test",
    )

# %%
_results_dict = {
    # "Adv": Adv_df,
    "GAdv": GAdv_df,
    # "DAdv": DAdv_df,
    # "GDAdv": GDAdv_df,
    "BTGAdv": BTGAdv_df,
    # "BTGDAdv": BTGDAdv_df,
    # "merged_GDAdv": merged_GDAdv,
    "merged_GAdv": merged_GAdv,
}

_final_df = model_comparasion(
    results_dict = _results_dict,
    pareto_selection="test",
    )
