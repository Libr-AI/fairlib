# %%
# from src.utils import model_selection, create_plots
from src.utils import create_plots, model_comparasion
# Replace model_selection with model_selection_parallel 
from src.load_results import model_selection_parallel as model_selection

# %%
Adv_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"hypertune4/Bios_both",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= "Adv",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    save_path = "results/Bios_both_Adv_df.pkl"
    )
# Out:
# [Parallel(n_jobs=20)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  32 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=20)]: Done 122 tasks      | elapsed:   31.1s
# [Parallel(n_jobs=20)]: Done 205 out of 205 | elapsed:   46.3s finished

# %%
create_plots(input_df = Adv_df)
# Out:
#                           index epoch      dev_rms_TPR           dev_accuracy  \
#                                  mean  var        mean       var         mean
# 37  (50.11872336272725, 1, 0.0)  11.0  6.5    0.744954  0.005354      0.66977
#
#                dev_DTO           test_rms_TPR           test_accuracy  \
#          var      mean       var         mean       var          mean
# 37  0.002145  0.206906  0.001954     0.796983  0.008362      0.674173
#
#               test_DTO           log_lambda final_DTO
#          var      mean       var
# 37  0.002187  0.252531  0.003953        1.7  0.208615

# %%
DAdv_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"hypertune5/Bios_both",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= "R_DAdv",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    save_path = "results/Bios_both_DAdv_df.pkl"
    )
# Out:
# [Parallel(n_jobs=20)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  32 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=20)]: Done 122 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=20)]: Done 248 tasks      | elapsed:   49.8s
# [Parallel(n_jobs=20)]: Done 410 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=20)]: Done 608 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=20)]: Done 842 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=20)]: Done 1025 out of 1025 | elapsed:  3.3min finished

# %%
create_plots(input_df = DAdv_df)
# Out:
#                  index epoch      dev_rms_TPR           dev_accuracy  \
#                         mean  var        mean       var         mean
# 204  (100.0, 3, 100.0)  14.6  5.3    0.778266  0.001033     0.655696
#
#                 dev_DTO           test_rms_TPR           test_accuracy  \
#           var      mean       var         mean       var          mean
# 204  0.000212  0.131867  0.002863     0.838852  0.000493      0.662791
#
#               test_DTO           final_DTO log_lambda
#          var      mean       var
# 204  0.00022  0.181781  0.001041  0.194832        2.0

# %%
GAdv_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"hypertune4/Bios_both",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= "GAdv",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    save_path = "results/Bios_both_GAdv_df.pkl"
    )
# Out:
# [Parallel(n_jobs=20)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  32 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=20)]: Done 122 tasks      | elapsed:   25.8s
# [Parallel(n_jobs=20)]: Done 205 out of 205 | elapsed:   40.6s finished

# %%
create_plots(
    input_df = GAdv_df
    )
# Out:
#                            index epoch       dev_rms_TPR            \
#                                   mean   var        mean       var
# 36  (39.810717055349734, 1, 0.0)   9.8  12.7    0.734267  0.000838
#
#    dev_accuracy             dev_DTO          test_rms_TPR            \
#            mean       var      mean      var         mean       var
# 36     0.700365  0.002613  0.193668  0.00015     0.766085  0.002335
#
#    test_accuracy            test_DTO           final_DTO log_lambda
#             mean       var      mean       var
# 36      0.707292  0.002417  0.261699  0.001399  0.156537        1.6

# %%
BTGAdv_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"hypertune4/Bios_both",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= "BTGAdv",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    save_path = "results/Bios_both_BTGAdv_df.pkl"
    )
# Out:
# [Parallel(n_jobs=20)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  32 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=20)]: Done 122 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=20)]: Done 205 out of 205 | elapsed:   40.6s finished

# %%
create_plots(
    input_df = BTGAdv_df, 
    )
# Out:
#                            index epoch      dev_rms_TPR            \
#                                   mean  var        mean       var
# 36  (39.810717055349734, 1, 0.0)  11.6  7.3     0.75443  0.001797
#
#    dev_accuracy             dev_DTO           test_rms_TPR            \
#            mean       var      mean       var         mean       var
# 36     0.684575  0.000262  0.171996  0.000974      0.81875  0.004021
#
#    test_accuracy           test_DTO           final_DTO log_lambda
#             mean      var      mean       var
# 36      0.689692  0.00028  0.213274  0.002884  0.230003        1.6

# %%
GDAdv_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"hypertune5/Bios_both",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= "GDAdv",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    save_path = "results/Bios_both_GDAdv_df.pkl"
    )
# Out:
# [Parallel(n_jobs=20)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  32 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=20)]: Done 122 tasks      | elapsed:   26.1s
# [Parallel(n_jobs=20)]: Done 248 tasks      | elapsed:   49.0s
# [Parallel(n_jobs=20)]: Done 410 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=20)]: Done 608 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=20)]: Done 842 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=20)]: Done 1025 out of 1025 | elapsed:  3.3min finished

# %%
create_plots(
    input_df = GDAdv_df, 
    )
# Out:
#                            index epoch       dev_rms_TPR            \
#                                   mean   var        mean       var
# 186  (50.11872336272725, 3, 0.1)  10.6  18.3    0.718914  0.002014
#
#     dev_accuracy             dev_DTO           test_rms_TPR            \
#             mean       var      mean       var         mean       var
# 186     0.721413  0.001263  0.188499  0.001407     0.763342  0.001429
#
#     test_accuracy            test_DTO           log_lambda final_DTO
#              mean       var      mean       var
# 186      0.726315  0.001124  0.241142  0.000396        1.7  0.139189

# %%
BTGDAdv_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"hypertune4/Bios_both",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= "DAdv",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    save_path = "results/Bios_both_BTGDAdv_df.pkl",
    )
# Out:
# [Parallel(n_jobs=20)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  32 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=20)]: Done 122 tasks      | elapsed:   25.3s
# [Parallel(n_jobs=20)]: Done 248 tasks      | elapsed:   48.5s
# [Parallel(n_jobs=20)]: Done 410 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=20)]: Done 608 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=20)]: Done 842 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=20)]: Done 1025 out of 1025 | elapsed:  3.3min finished

# %%
create_plots(
    input_df = BTGDAdv_df, 
    )
# Out:
#                             index epoch      dev_rms_TPR            \
#                                    mean  var        mean       var
# 191  (63.095734448019364, 3, 0.1)  10.0  7.0    0.775048  0.001115
#
#     dev_accuracy             dev_DTO           test_rms_TPR            \
#             mean       var      mean       var         mean       var
# 191     0.677948  0.001151  0.164195  0.000059     0.860386  0.001414
#
#     test_accuracy            test_DTO           log_lambda final_DTO
#              mean       var      mean       var
# 191      0.684974  0.001112  0.183879  0.000777        1.8  0.203966

# %%
FairBatch_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"FairBatch/Bios_both",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= "FairBatch",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    index_column_names = ['DyBTObj', 'DyBTalpha', 'DyBTinit'],
    save_path = "results/Bios_both_FairBatch_df.pkl"
    )
# Out:
# [Parallel(n_jobs=20)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  32 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=20)]: Done 122 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=20)]: Done 205 out of 205 | elapsed:   37.2s finished

# %%
BTFairBatch_df = model_selection(
    results_dir= r"G:\Experimental_results",
    project_dir= r"FairBatch/Bios_both",
    checkpoint_dir= "models",
    checkpoint_name= "checkpoint_epoch",
    model_id= "BTInitFairBatch",
    GAP_metric_name = "rms_TPR",
    Performance_metric_name = "accuracy",
    selection_criterion = "DTO",
    index_column_names = ['DyBTObj', 'DyBTalpha', 'DyBTinit'],
    save_path = "results/Bios_both_BTFairBatch_df.pkl"
    )
# Out:
# [Parallel(n_jobs=20)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  32 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=20)]: Done 122 tasks      | elapsed:   23.2s
# [Parallel(n_jobs=20)]: Done 205 out of 205 | elapsed:   34.9s finished

# %%
_results_dict = {
    "Adv": Adv_df,
    "GAdv": GAdv_df,
    "DAdv": DAdv_df,
    "GDAdv": GDAdv_df,
    "BTGAdv": BTGAdv_df,
    "BTGDAdv": BTGDAdv_df,
    "FairBatch": FairBatch_df,
    "BTFairBatch": BTFairBatch_df,
}

_final_df = model_comparasion(
    results_dict = _results_dict,
    pareto_selection="test",
    )

# %%
_final_df = model_comparasion(
    results_dict = _results_dict,
    pareto_selection="dev",
    )

# %%
import pandas as pd
merged_GDAdv = pd.concat([GDAdv_df, BTGDAdv_df])
merged_GAdv = pd.concat([GAdv_df, BTGAdv_df])

# %%
_results_dict = {
    "Adv": Adv_df,
    "GAdv": merged_GAdv,
    "DAdv": DAdv_df,
    "GDAdv": merged_GDAdv,
    "FairBatch": FairBatch_df,
    "BTFairBatch": BTFairBatch_df,
}

_final_df = model_comparasion(
    results_dict = _results_dict,
    pareto_selection="test",
    )

# %%
_results_dict = {
    "FairBatch": FairBatch_df,
    "BTFairBatch": BTFairBatch_df,
}

_final_df = model_comparasion(
    results_dict = _results_dict,
    pareto_selection="test",
    )

# %%
_results_dict = {
    "Adv": Adv_df,
    "GAdv": merged_GAdv,
    "DAdv": DAdv_df,
    "GDAdv": merged_GDAdv,
    # "FairBatch": FairBatch_df,
    # "BTFairBatch": BTFairBatch_df,
}

_final_df = model_comparasion(
    results_dict = _results_dict,
    pareto_selection="test",
    )
